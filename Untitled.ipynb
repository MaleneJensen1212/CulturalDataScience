# %%
# %pip install lxml
import pandas as pd

# %pip install seaborn
import seaborn as sns

# %pip install matplot
import matplot as plt
# Out:
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (5.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.10/site-packages (from seaborn) (2.1.0)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.10/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/conda/lib/python3.10/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting matplot
#   Downloading matplot-0.1.9-py2.py3-none-any.whl.metadata (241 bytes)
# Collecting pyloco>=0.0.134 (from matplot)
#   Downloading pyloco-0.0.139-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: matplotlib>=3.1.1 in /opt/conda/lib/python3.10/site-packages (from matplot) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.1->matplot) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.1->matplot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.1->matplot) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.1->matplot) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.1->matplot) (2.1.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.1->matplot) (24.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.1->matplot) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.1->matplot) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.1->matplot) (2.9.0)
# Collecting ushlex (from pyloco>=0.0.134->matplot)
#   Downloading ushlex-0.99.1.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from pyloco>=0.0.134->matplot) (1.8.0)
# Collecting twine (from pyloco>=0.0.134->matplot)
#   Downloading twine-5.1.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting typing (from pyloco>=0.0.134->matplot)
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#   Preparing metadata (setup.py) ... done
# Collecting SimpleWebSocketServer (from pyloco>=0.0.134->matplot)
#   Downloading SimpleWebSocketServer-0.1.2.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->matplot) (1.16.0)
# Collecting pkginfo>=1.8.1 (from twine->pyloco>=0.0.134->matplot)
#   Downloading pkginfo-1.11.1-py3-none-any.whl.metadata (11 kB)
# Collecting readme-renderer>=35.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading readme_renderer-44.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests>=2.20 in /opt/conda/lib/python3.10/site-packages (from twine->pyloco>=0.0.134->matplot) (2.31.0)
# Collecting requests-toolbelt!=0.9.0,>=0.8.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.10/site-packages (from twine->pyloco>=0.0.134->matplot) (2.2.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /opt/conda/lib/python3.10/site-packages (from twine->pyloco>=0.0.134->matplot) (8.4.0)
# Collecting keyring>=15.1 (from twine->pyloco>=0.0.134->matplot)
#   Downloading keyring-25.4.1-py3-none-any.whl.metadata (20 kB)
# Collecting rfc3986>=1.4.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting rich>=12.0.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading rich-13.8.1-py3-none-any.whl.metadata (18 kB)
# Collecting pkginfo>=1.8.1 (from twine->pyloco>=0.0.134->matplot)
#   Downloading pkginfo-1.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=3.6->twine->pyloco>=0.0.134->matplot) (3.20.1)
# Collecting jaraco.classes (from keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading jaraco.classes-3.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting jaraco.functools (from keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading jaraco.functools-4.1.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting jaraco.context (from keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading jaraco.context-6.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting SecretStorage>=3.2 (from keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading SecretStorage-3.3.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting jeepney>=0.4.2 (from keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading jeepney-0.8.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot)
#   Downloading nh3-0.2.18-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting docutils>=0.21.2 (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot)
#   Downloading docutils-0.21.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: Pygments>=2.5.1 in /opt/conda/lib/python3.10/site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2024.7.4)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->pyloco>=0.0.134->matplot)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: cryptography>=2.0 in /opt/conda/lib/python3.10/site-packages (from SecretStorage>=3.2->keyring>=15.1->twine->pyloco>=0.0.134->matplot) (43.0.0)
# Collecting more-itertools (from jaraco.classes->keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading more_itertools-10.5.0-py3-none-any.whl.metadata (36 kB)
# Collecting backports.tarfile (from jaraco.context->keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading backports.tarfile-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=15.1->twine->pyloco>=0.0.134->matplot) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=15.1->twine->pyloco>=0.0.134->matplot) (2.22)
# Downloading matplot-0.1.9-py2.py3-none-any.whl (5.0 kB)
# Downloading pyloco-0.0.139-py2.py3-none-any.whl (60 kB)
# Downloading twine-5.1.1-py3-none-any.whl (38 kB)
# Downloading keyring-25.4.1-py3-none-any.whl (38 kB)
# Downloading pkginfo-1.10.0-py3-none-any.whl (30 kB)
# Downloading readme_renderer-44.0-py3-none-any.whl (13 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Downloading rich-13.8.1-py3-none-any.whl (241 kB)
# Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 kB 823.0 kB/s eta 0:00:00a 0:00:01
# Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading nh3-0.2.18-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (769 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.2/769.2 kB 6.6 MB/s eta 0:00:00
# Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Downloading jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# Downloading jaraco.context-6.0.1-py3-none-any.whl (6.8 kB)
# Downloading jaraco.functools-4.1.0-py3-none-any.whl (10 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading backports.tarfile-1.2.0-py3-none-any.whl (30 kB)
# Downloading more_itertools-10.5.0-py3-none-any.whl (60 kB)
# Building wheels for collected packages: SimpleWebSocketServer, typing, ushlex
#   Building wheel for SimpleWebSocketServer (setup.py) ... done
#   Created wheel for SimpleWebSocketServer: filename=SimpleWebSocketServer-0.1.2-py3-none-any.whl size=9664 sha256=4a8f2e5e787ec717d02f0ad4a8be6ae01ce8362ba91fb6fabf935315c4dd891d
#   Stored in directory: /home/ucloud/.cache/pip/wheels/af/cb/9d/23ef01c9c26b978be6d29ed456d7348abd0e96b1563049bd63
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26306 sha256=9868a8c3559682d5da7a28a9861084390e2cdc45caaad9308ac0e5616cec9109
#   Stored in directory: /home/ucloud/.cache/pip/wheels/7c/d0/9e/1f26ebb66d9e1732e4098bc5a6c2d91f6c9a529838f0284890
#   Building wheel for ushlex (setup.py) ... done
#   Created wheel for ushlex: filename=ushlex-0.99.1-py3-none-any.whl size=4394 sha256=a7f160b5db00528b38bf636de9c372f9c0eddc45a103ff8f7fafb8163a03c7de
#   Stored in directory: /home/ucloud/.cache/pip/wheels/fd/e4/80/4de44668798392eb2f5b24f0130df2f5d28b43cb256bf9c1f9
# Successfully built SimpleWebSocketServer typing ushlex
# Installing collected packages: ushlex, SimpleWebSocketServer, nh3, typing, rfc3986, pkginfo, more-itertools, mdurl, jeepney, docutils, backports.tarfile, requests-toolbelt, readme-renderer, markdown-it-py, jaraco.functools, jaraco.context, jaraco.classes, SecretStorage, rich, keyring, twine, pyloco, matplot
# Successfully installed SecretStorage-3.3.3 SimpleWebSocketServer-0.1.2 backports.tarfile-1.2.0 docutils-0.21.2 jaraco.classes-3.4.0 jaraco.context-6.0.1 jaraco.functools-4.1.0 jeepney-0.8.0 keyring-25.4.1 markdown-it-py-3.0.0 matplot-0.1.9 mdurl-0.1.2 more-itertools-10.5.0 nh3-0.2.18 pkginfo-1.10.0 pyloco-0.0.139 readme-renderer-44.0 requests-toolbelt-1.0.0 rfc3986-2.0.0 rich-13.8.1 twine-5.1.1 typing-3.7.4.3 ushlex-0.99.1
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("mp_data1.csv")
df.head(30)
# Out:
#       ID             sender    sender_type sender_id    ended_on  duration  \
# 0   4549            Wecome0  canvas.Screen         0     timeout     493.6
# 1   4549            Wecome1  canvas.Screen         1     timeout     492.2
# 2   4549            Wecome2  canvas.Screen         2     timeout     494.0
# 3   4549            Wecome3  canvas.Screen         3     timeout     508.6
# 4   4549      Instructions1  canvas.Screen         4    response   22964.5
# 5   4549    Instructions 1a  canvas.Screen         5    response   11462.3
# 6   4549      Instructions2  canvas.Screen         6    response    4469.2
# 7   4549      Instructions3  canvas.Screen         7    response    7697.3
# 8   4549      Instructions4  canvas.Screen         8    response    2639.8
# 9   4549      Instructions5  canvas.Screen         9    response    6446.7
# 10  4549           fixation  canvas.Screen    10_0_0     timeout     537.4
# 11  4549              mask1  canvas.Screen    10_0_1     timeout      49.0
# 12  4549              prime  canvas.Screen    10_0_2     timeout      43.4
# 13  4549              mask2  canvas.Screen    10_0_3     timeout      44.0
# 14  4549             target  canvas.Screen    10_0_4    response     840.0
# 15  4549  Practice Sequence  flow.Sequence      10_0  completion    1513.8
# 16  4549           fixation  canvas.Screen    10_1_0     timeout     541.1
# 17  4549              mask1  canvas.Screen    10_1_1     timeout      50.4
# 18  4549              prime  canvas.Screen    10_1_2     timeout      43.8
# 19  4549              mask2  canvas.Screen    10_1_3     timeout      45.3
# 20  4549             target  canvas.Screen    10_1_4    response     643.3
# 21  4549  Practice Sequence  flow.Sequence      10_1  completion    1323.9
# 22  4549           fixation  canvas.Screen    10_2_0     timeout     543.2
# 23  4549              mask1  canvas.Screen    10_2_1     timeout      46.0
# 24  4549              prime  canvas.Screen    10_2_2     timeout      46.6
# 25  4549              mask2  canvas.Screen    10_2_3     timeout      44.7
# 26  4549             target  canvas.Screen    10_2_4    response     782.7
# 27  4549  Practice Sequence  flow.Sequence      10_2  completion    1463.2
# 28  4549           fixation  canvas.Screen    10_3_0     timeout     542.7
# 29  4549              mask1  canvas.Screen    10_3_1     timeout      54.6
#
#     time_run  time_render  time_show  time_end  ...          response  \
# 0     1601.9     1596.916     1600.1    2077.6  ...               NaN
# 1     2080.9     2077.600     2093.7    2569.5  ...               NaN
# 2     2571.2     2569.500     2585.9    3063.0  ...               NaN
# 3     3065.5     3063.000     3079.9    3572.5  ...               NaN
# 4     3573.9     3572.500     3588.5   26553.0  ...               NaN
# 5    26562.8    26563.374    26580.4   38042.7  ...               NaN
# 6    38050.3    38046.800    38067.2   42536.4  ...               NaN
# 7    42544.9    42534.900    42556.0   50253.3  ...               NaN
# 8    50262.0    50272.358    50278.6   52918.4  ...               NaN
# 9    52926.0    52912.900    52939.8   59386.5  ...               NaN
# 10   59393.0    59390.300    59411.7   59932.6  ...               NaN
# 11   59934.9    59932.600    59949.1   59982.6  ...               NaN
# 12   59984.1    59982.600    59998.1   60026.7  ...               NaN
# 13   60029.6    60026.700    60041.5   60070.4  ...               NaN
# 14   60076.1    60070.400    60085.5   60925.5  ...  response_natural
# 15   59392.9    59390.300    59411.7   60925.5  ...               NaN
# 16   60946.7    60946.800    60970.3   61495.1  ...               NaN
# 17   61498.2    61495.100    61511.4   61544.9  ...               NaN
# 18   61547.6    61544.900    61561.8   61589.2  ...               NaN
# 19   61594.4    61589.200    61605.6   61635.1  ...               NaN
# 20   61641.0    61635.100    61650.9   62294.2  ...  response_natural
# 21   60946.6    60946.800    60970.3   62294.2  ...               NaN
# 22   62302.4    62300.874    62319.9   62846.5  ...               NaN
# 23   62849.4    62846.500    62863.1   62896.0  ...               NaN
# 24   62897.5    62896.000    62909.1   62940.1  ...               NaN
# 25   62943.3    62940.100    62955.7   62985.4  ...               NaN
# 26   62991.0    62985.400    63000.4   63783.1  ...  response_manmade
# 27   62302.3    62300.874    62319.9   63783.1  ...               NaN
# 28   63803.6    63800.368    63818.1   64344.5  ...               NaN
# 29   64346.1    64344.500    64360.8   64393.5  ...               NaN
#
#     response_action    prime target condition soa_condition congruence  \
# 0               NaN      NaN    NaN       NaN           NaN        NaN
# 1               NaN      NaN    NaN       NaN           NaN        NaN
# 2               NaN      NaN    NaN       NaN           NaN        NaN
# 3               NaN      NaN    NaN       NaN           NaN        NaN
# 4          keypress      NaN    NaN       NaN           NaN        NaN
# 5          keypress      NaN    NaN       NaN           NaN        NaN
# 6          keypress      NaN    NaN       NaN           NaN        NaN
# 7          keypress      NaN    NaN       NaN           NaN        NaN
# 8          keypress      NaN    NaN       NaN           NaN        NaN
# 9   keypress(Space)      NaN    NaN       NaN           NaN        NaN
# 10              NaN   snjghf  SHEEP  practice      practice   practice
# 11              NaN   snjghf  SHEEP  practice      practice   practice
# 12              NaN   snjghf  SHEEP  practice      practice   practice
# 13              NaN   snjghf  SHEEP  practice      practice   practice
# 14      keypress(n)   snjghf  SHEEP  practice      practice   practice
# 15              NaN   snjghf  SHEEP  practice      practice   practice
# 16              NaN  abjdhjs  HORSE  practice      practice   practice
# 17              NaN  abjdhjs  HORSE  practice      practice   practice
# 18              NaN  abjdhjs  HORSE  practice      practice   practice
# 19              NaN  abjdhjs  HORSE  practice      practice   practice
# 20      keypress(n)  abjdhjs  HORSE  practice      practice   practice
# 21              NaN  abjdhjs  HORSE  practice      practice   practice
# 22              NaN   nvoiuh  HOUSE  practice      practice   practice
# 23              NaN   nvoiuh  HOUSE  practice      practice   practice
# 24              NaN   nvoiuh  HOUSE  practice      practice   practice
# 25              NaN   nvoiuh  HOUSE  practice      practice   practice
# 26      keypress(m)   nvoiuh  HOUSE  practice      practice   practice
# 27              NaN   nvoiuh  HOUSE  practice      practice   practice
# 28              NaN   iweonf   BOAT  practice      practice   practice
# 29              NaN   iweonf   BOAT  practice      practice   practice
#
#    correct_response correctResponse correct
# 0               NaN             NaN     NaN
# 1               NaN             NaN     NaN
# 2               NaN             NaN     NaN
# 3               NaN             NaN     NaN
# 4               NaN             NaN     NaN
# 5               NaN             NaN     NaN
# 6               NaN             NaN     NaN
# 7               NaN             NaN     NaN
# 8               NaN             NaN     NaN
# 9               NaN             NaN     NaN
# 10                n             NaN     NaN
# 11                n             NaN     NaN
# 12                n             NaN     NaN
# 13                n             NaN     NaN
# 14                n               n   False
# 15                n             NaN     NaN
# 16                n             NaN     NaN
# 17                n             NaN     NaN
# 18                n             NaN     NaN
# 19                n             NaN     NaN
# 20                n               n   False
# 21                n             NaN     NaN
# 22                m             NaN     NaN
# 23                m             NaN     NaN
# 24                m             NaN     NaN
# 25                m             NaN     NaN
# 26                m               m   False
# 27                m             NaN     NaN
# 28                m             NaN     NaN
# 29                m             NaN     NaN
#
# [30 rows x 23 columns]

# %%
#Cleaning data:
#Remove welcome - We only wanan know the reponsetime of the target words
#Reatin rows where sender = "target"
df = df[df['sender'] == 'target']
df.head(20)
# Out:
#        ID  sender    sender_type    sender_id  ended_on  duration  time_run  \
# 14   4549  target  canvas.Screen       10_0_4  response     840.0   60076.1
# 20   4549  target  canvas.Screen       10_1_4  response     643.3   61641.0
# 26   4549  target  canvas.Screen       10_2_4  response     782.7   62991.0
# 32   4549  target  canvas.Screen       10_3_4  response     839.9   64501.5
# 41   4549  target  canvas.Screen   12_0_0_0_5  response     742.4   67989.8
# 48   4549  target  canvas.Screen   12_0_0_1_5  response     861.8   69510.8
# 55   4549  target  canvas.Screen   12_0_0_2_5  response     725.9   71152.0
# 62   4549  target  canvas.Screen   12_0_0_3_5  response     796.7   72671.6
# 69   4549  target  canvas.Screen   12_0_0_4_5  response     815.1   74261.2
# 76   4549  target  canvas.Screen   12_0_0_5_5  response     673.5   75869.0
# 83   4549  target  canvas.Screen   12_0_0_6_5  response    1158.1   77305.7
# 90   4549  target  canvas.Screen   12_0_0_7_5  response    1092.2   79229.8
# 97   4549  target  canvas.Screen   12_0_0_8_5  response     853.4   81104.9
# 104  4549  target  canvas.Screen   12_0_0_9_5  response     910.4   82726.6
# 111  4549  target  canvas.Screen  12_0_0_10_5  response     820.8   84404.5
# 118  4549  target  canvas.Screen  12_0_0_11_5  response     764.3   86007.1
# 125  4549  target  canvas.Screen  12_0_0_12_5  response     762.8   87542.2
# 132  4549  target  canvas.Screen  12_0_0_13_5  response    1060.8   89095.1
# 139  4549  target  canvas.Screen  12_0_0_14_5  response     866.7   90938.8
# 146  4549  target  canvas.Screen  12_0_0_15_5  response    1085.8   92588.0
#
#      time_render  time_show  time_end  ...          response response_action  \
# 14       60070.4    60085.5   60925.5  ...  response_natural     keypress(n)
# 20       61635.1    61650.9   62294.2  ...  response_natural     keypress(n)
# 26       62985.4    63000.4   63783.1  ...  response_manmade     keypress(m)
# 32       64499.8    64513.8   65353.7  ...  response_manmade     keypress(m)
# 41       67987.1    67997.8   68740.2  ...  response_manmade     keypress(m)
# 48       69507.9    69519.9   70381.7  ...  response_natural     keypress(n)
# 55       71148.9    71161.3   71887.2  ...  response_natural     keypress(n)
# 62       72666.9    72680.7   73477.4  ...  response_natural     keypress(n)
# 69       74258.2    74271.4   75086.5  ...  response_manmade     keypress(m)
# 76       75866.7    75878.6   76552.1  ...  response_manmade     keypress(m)
# 83       77304.6    77315.3   78473.4  ...  response_natural     keypress(n)
# 90       79228.3    79241.3   80333.5  ...  response_manmade     keypress(m)
# 97       81103.4    81115.1   81968.5  ...  response_natural     keypress(n)
# 104      82724.0    82735.0   83645.4  ...  response_manmade     keypress(m)
# 111      84401.6    84413.3   85234.1  ...  response_manmade     keypress(m)
# 118      86004.2    86017.6   86781.9  ...  response_natural     keypress(n)
# 125      87539.4    87552.6   88315.4  ...  response_natural     keypress(n)
# 132      89093.6    89112.3   90173.1  ...  response_manmade     keypress(m)
# 139      90936.9    90948.3   91815.0  ...  response_manmade     keypress(m)
# 146      92585.3    92599.2   93685.0  ...  response_natural     keypress(n)
#
#        prime target        condition soa_condition   congruence  \
# 14    snjghf  SHEEP         practice      practice     practice
# 20   abjdhjs  HORSE         practice      practice     practice
# 26    nvoiuh  HOUSE         practice      practice     practice
# 32    iweonf   BOAT         practice      practice     practice
# 41      desk  CANDY  Inc_Synth_Synth          long  incongruent
# 48     shark   HILL      Inc_Nat_Nat          long  incongruent
# 55      peas   PEAS          Con_Nat          long    congruent
# 62      plum   PLUM          Con_Nat          long    congruent
# 69      deck  PLATE  Inc_Synth_Synth          long  incongruent
# 76      bell  WHEEL  Inc_Synth_Synth          long  incongruent
# 83     stick  STICK          Con_Nat          long    congruent
# 90     eagle  WAGON    Inc_Nat_Synth          long  incongruent
# 97      mall   BUSH    Inc_Synth_Nat          long  incongruent
# 104    jeans  JEANS        Con_Synth          long    congruent
# 111    ferry  FERRY        Con_Synth          long    congruent
# 118    stone  STONE          Con_Nat          long    congruent
# 125    bunny   ROSE      Inc_Nat_Nat          long  incongruent
# 132    apron  APRON        Con_Synth          long    congruent
# 139    canoe  CANOE        Con_Synth          long    congruent
# 146     clam   CLAM          Con_Nat          long    congruent
#
#     correct_response correctResponse correct
# 14                 n               n   False
# 20                 n               n   False
# 26                 m               m   False
# 32                 m               m   False
# 41                 m               m   False
# 48                 m               m   False
# 55                 n               n   False
# 62                 n               n   False
# 69                 m               m   False
# 76                 m               m   False
# 83                 n               n   False
# 90                 m               m   False
# 97                 n               n   False
# 104                m               m   False
# 111                m               m   False
# 118                n               n   False
# 125                m               m   False
# 132                m               m   False
# 139                m               m   False
# 146                n               n   False
#
# [20 rows x 23 columns]

# %%
#Find all unique words in 'sender'-column
set(df['sender']) #There is only 'target' as we wanted
# Out:
# {'target'}

# %%
#response_action is the key they pressed
#correct_response is the correct response
#Make response_action only contain the key they reponded

df['response_action'] = df['response_action'].str.replace('keypress(', '')
df['response_action'] = df['response_action'].str.replace(')', '')
df.head()
# Out:
#       ID  sender    sender_type   sender_id  ended_on  duration  time_run  \
# 14  4549  target  canvas.Screen      10_0_4  response     840.0   60076.1
# 20  4549  target  canvas.Screen      10_1_4  response     643.3   61641.0
# 26  4549  target  canvas.Screen      10_2_4  response     782.7   62991.0
# 32  4549  target  canvas.Screen      10_3_4  response     839.9   64501.5
# 41  4549  target  canvas.Screen  12_0_0_0_5  response     742.4   67989.8
#
#     time_render  time_show  time_end  ...          response response_action  \
# 14      60070.4    60085.5   60925.5  ...  response_natural               n
# 20      61635.1    61650.9   62294.2  ...  response_natural               n
# 26      62985.4    63000.4   63783.1  ...  response_manmade               m
# 32      64499.8    64513.8   65353.7  ...  response_manmade               m
# 41      67987.1    67997.8   68740.2  ...  response_manmade               m
#
#       prime target        condition soa_condition   congruence  \
# 14   snjghf  SHEEP         practice      practice     practice
# 20  abjdhjs  HORSE         practice      practice     practice
# 26   nvoiuh  HOUSE         practice      practice     practice
# 32   iweonf   BOAT         practice      practice     practice
# 41     desk  CANDY  Inc_Synth_Synth          long  incongruent
#
#    correct_response correctResponse correct
# 14                n               n   False
# 20                n               n   False
# 26                m               m   False
# 32                m               m   False
# 41                m               m   False
#
# [5 rows x 23 columns]

# %%
df['correct'] = df['response_action'] == df['correct_response']
df.head()
# Out:
#       ID  sender    sender_type   sender_id  ended_on  duration  time_run  \
# 14  4549  target  canvas.Screen      10_0_4  response     840.0   60076.1
# 20  4549  target  canvas.Screen      10_1_4  response     643.3   61641.0
# 26  4549  target  canvas.Screen      10_2_4  response     782.7   62991.0
# 32  4549  target  canvas.Screen      10_3_4  response     839.9   64501.5
# 41  4549  target  canvas.Screen  12_0_0_0_5  response     742.4   67989.8
#
#     time_render  time_show  time_end  ...          response response_action  \
# 14      60070.4    60085.5   60925.5  ...  response_natural               n
# 20      61635.1    61650.9   62294.2  ...  response_natural               n
# 26      62985.4    63000.4   63783.1  ...  response_manmade               m
# 32      64499.8    64513.8   65353.7  ...  response_manmade               m
# 41      67987.1    67997.8   68740.2  ...  response_manmade               m
#
#       prime target        condition soa_condition   congruence  \
# 14   snjghf  SHEEP         practice      practice     practice
# 20  abjdhjs  HORSE         practice      practice     practice
# 26   nvoiuh  HOUSE         practice      practice     practice
# 32   iweonf   BOAT         practice      practice     practice
# 41     desk  CANDY  Inc_Synth_Synth          long  incongruent
#
#    correct_response correctResponse correct
# 14                n               n    True
# 20                n               n    True
# 26                m               m    True
# 32                m               m    True
# 41                m               m    True
#
# [5 rows x 23 columns]

# %%
set(df['correct'])
# Out:
# {False, True}

# %%
list(df)
# Out:
# ['ID',
#  'sender',
#  'sender_type',
#  'sender_id',
#  'ended_on',
#  'duration',
#  'time_run',
#  'time_render',
#  'time_show',
#  'time_end',
#  'time_commit',
#  'timestamp',
#  'time_switch',
#  'response',
#  'response_action',
#  'prime',
#  'target',
#  'condition',
#  'soa_condition',
#  'congruence',
#  'correct_response',
#  'correctResponse',
#  'correct']

# %%
#The columns I want in my dataframe: ID, duration, condition, soa_condition, correct
data = df.loc[:, ['ID', 'duration', 'condition', 'soa_condition', 'correct', 'congruence']]
data.head()
# Out:
#       ID  duration        condition soa_condition  correct   congruence
# 14  4549     840.0         practice      practice     True     practice
# 20  4549     643.3         practice      practice     True     practice
# 26  4549     782.7         practice      practice     True     practice
# 32  4549     839.9         practice      practice     True     practice
# 41  4549     742.4  Inc_Synth_Synth          long     True  incongruent

# %%
#Remove the rows where condition is practice
data = data[data['condition'] != 'practice']
data.head(30)
# Out:
#        ID  duration        condition soa_condition  correct   congruence
# 41   4549     742.4  Inc_Synth_Synth          long     True  incongruent
# 48   4549     861.8      Inc_Nat_Nat          long    False  incongruent
# 55   4549     725.9          Con_Nat          long     True    congruent
# 62   4549     796.7          Con_Nat          long     True    congruent
# 69   4549     815.1  Inc_Synth_Synth          long     True  incongruent
# 76   4549     673.5  Inc_Synth_Synth          long     True  incongruent
# 83   4549    1158.1          Con_Nat          long     True    congruent
# 90   4549    1092.2    Inc_Nat_Synth          long     True  incongruent
# 97   4549     853.4    Inc_Synth_Nat          long     True  incongruent
# 104  4549     910.4        Con_Synth          long     True    congruent
# 111  4549     820.8        Con_Synth          long     True    congruent
# 118  4549     764.3          Con_Nat          long     True    congruent
# 125  4549     762.8      Inc_Nat_Nat          long    False  incongruent
# 132  4549    1060.8        Con_Synth          long     True    congruent
# 139  4549     866.7        Con_Synth          long     True    congruent
# 146  4549    1085.8          Con_Nat          long     True    congruent
# 153  4549     817.4      Inc_Nat_Nat          long    False  incongruent
# 160  4549     843.0          Con_Nat          long     True    congruent
# 167  4549     645.6          Con_Nat          long     True    congruent
# 174  4549     874.1        Con_Synth          long     True    congruent
# 181  4549     955.6  Inc_Synth_Synth          long     True  incongruent
# 188  4549     918.8  Inc_Synth_Synth          long     True  incongruent
# 195  4549    1007.8      Inc_Nat_Nat          long    False  incongruent
# 202  4549    1072.5    Inc_Synth_Nat          long    False  incongruent
# 209  4549     768.7        Con_Synth          long     True    congruent
# 216  4549    1339.6        Con_Synth          long     True    congruent
# 223  4549     564.5          Con_Nat          long     True    congruent
# 230  4549    1100.0          Con_Nat          long     True    congruent
# 237  4549    1158.7        Con_Synth          long     True    congruent
# 244  4549    2007.7        Con_Synth          long    False    congruent

# %%
#Make a figure visualisation of the data
#Pointplot using seaborn package
sns.pointplot(data=data, x="soa_condition", y="duration", hue="congruence", order=["short", "long"])
# Out:
# <Axes: xlabel='soa_condition', ylabel='duration'>

# %%
#Now only looking at the data that is correct in repsonse
data = data[data["correct"] == True]
data.head()
# Out:
#       ID  duration        condition soa_condition  correct   congruence
# 41  4549     742.4  Inc_Synth_Synth          long     True  incongruent
# 55  4549     725.9          Con_Nat          long     True    congruent
# 62  4549     796.7          Con_Nat          long     True    congruent
# 69  4549     815.1  Inc_Synth_Synth          long     True  incongruent
# 76  4549     673.5  Inc_Synth_Synth          long     True  incongruent

# %%
#Doing the same visualisation to see whther there is a difference when correct = True or when correct contain both True and False
sns.pointplot(data=data, x="soa_condition", y="duration", hue="congruence", order=["short", "long"])
plt.ylab("RT (ms)")
plt.xlab("SOA Condition")
plt.title("my awesome plot")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 3
#       1 #Doing the same visualisation to see whther there is a difference when correct = True or when correct contain both True and False
#       2 sns.pointplot(data=data, x="soa_condition", y="duration", hue="congruence", order=["short", "long"])
# ----> 3 plt.ylab("RT (ms)")
#       4 plt.xlab("SOA Condition")
#       5 plt.title("my awesome plot")
#
# AttributeError: module 'matplot' has no attribute 'ylab'

# %%
sns.distplot(data["duration"])
# Out:
# /tmp/ipykernel_409/2188402406.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["duration"])
# <Axes: xlabel='duration', ylabel='Density'>
